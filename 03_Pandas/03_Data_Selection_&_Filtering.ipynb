# %%
import pandas as pd

# %%
movieData = pd.read_csv("movie_data.csv")

# %%
movieData
# Out:
#                    Actor                      Film  Year      Genre  \
# 0      Leonardo DiCaprio                 Inception  2010     Sci-Fi
# 1      Leonardo DiCaprio                   Titanic  1997    Romance
# 2      Robert Downey Jr.                  Iron Man  2008     Action
# 3      Robert Downey Jr.         Avengers: Endgame  2019     Action
# 4         Christian Bale           The Dark Knight  2008     Action
# 5         Christian Bale             Batman Begins  2005     Action
# 6              Tom Hanks              Forrest Gump  1994      Drama
# 7              Tom Hanks                 Cast Away  2000      Drama
# 8           Keanu Reeves                The Matrix  1999     Sci-Fi
# 9           Keanu Reeves                 John Wick  2014     Action
# 10             Brad Pitt                Fight Club  1999      Drama
# 11             Brad Pitt               World War Z  2013     Action
# 12           Johnny Depp  Pirates of the Caribbean  2003  Adventure
# ...

# %%
movieData['Actor']
# Out:
# 0        Leonardo DiCaprio
# 1        Leonardo DiCaprio
# 2        Robert Downey Jr.
# 3        Robert Downey Jr.
# 4           Christian Bale
# 5           Christian Bale
# 6                Tom Hanks
# 7                Tom Hanks
# 8             Keanu Reeves
# 9             Keanu Reeves
# 10               Brad Pitt
# 11               Brad Pitt
# 12             Johnny Depp
# 13             Johnny Depp
# 14              Will Smith
# 15              Will Smith
# 16              Matt Damon
# 17              Matt Damon
# 18             Chris Evans
# 19             Chris Evans
# 20      Scarlett Johansson
# 21      Scarlett Johansson
# 22       Denzel Washington
# 23       Denzel Washington
# 24          Morgan Freeman
# 25          Morgan Freeman
# 26         Chris Hemsworth
# 27         Chris Hemsworth
# 28            Hugh Jackman
# 29            Hugh Jackman
# 30            Ryan Gosling
# 31            Ryan Gosling
# 32           Mark Wahlberg
# 33           Mark Wahlberg
# ...

# %%
movieData[['Actor', 'IMDB']]
# Out:
#                    Actor  IMDB
# 0      Leonardo DiCaprio   8.8
# 1      Leonardo DiCaprio   7.9
# 2      Robert Downey Jr.   7.9
# 3      Robert Downey Jr.   8.4
# 4         Christian Bale   9.0
# 5         Christian Bale   8.2
# 6              Tom Hanks   8.8
# 7              Tom Hanks   7.8
# 8           Keanu Reeves   8.7
# 9           Keanu Reeves   7.4
# 10             Brad Pitt   8.8
# 11             Brad Pitt   7.0
# 12           Johnny Depp   8.1
# 13           Johnny Depp   7.9
# 14            Will Smith   7.3
# 15            Will Smith   7.2
# 16            Matt Damon   8.0
# 17            Matt Damon   7.9
# 18           Chris Evans   6.9
# 19           Chris Evans   8.4
# 20    Scarlett Johansson   6.4
# 21    Scarlett Johansson   6.7
# 22     Denzel Washington   7.7
# 23     Denzel Washington   7.2
# 24        Morgan Freeman   9.3
# 25        Morgan Freeman   8.6
# 26       Chris Hemsworth   7.0
# 27       Chris Hemsworth   6.8
# 28          Hugh Jackman   8.1
# ...

# %%
movieData.loc[1]
# Out:
# Actor        Leonardo DiCaprio
# Film                   Titanic
# Year                      1997
# Genre                  Romance
# BoxOffice                 2200
# IMDB                       7.9
# Name: 1, dtype: object

# %%
movieData.iloc[1]
# Out:
# Actor        Leonardo DiCaprio
# Film                   Titanic
# Year                      1997
# Genre                  Romance
# BoxOffice                 2200
# IMDB                       7.9
# Name: 1, dtype: object

# %%
movieData.loc[24, 'IMDB']
# Out:
# np.float64(9.3)

# %%
movieData.iloc[24, 5]
# Out:
# np.float64(9.3)

# %%
movieData.loc[0:4, ["Actor", "Film", "Genre", "IMDB"]]
# Out:
#                Actor               Film    Genre  IMDB
# 0  Leonardo DiCaprio          Inception   Sci-Fi   8.8
# 1  Leonardo DiCaprio            Titanic  Romance   7.9
# 2  Robert Downey Jr.           Iron Man   Action   7.9
# 3  Robert Downey Jr.  Avengers: Endgame   Action   8.4
# 4     Christian Bale    The Dark Knight   Action   9.0

# %%
movieData.iloc[0:4, [0, 1, 3, 5]]
# Out:
#                Actor               Film    Genre  IMDB
# 0  Leonardo DiCaprio          Inception   Sci-Fi   8.8
# 1  Leonardo DiCaprio            Titanic  Romance   7.9
# 2  Robert Downey Jr.           Iron Man   Action   7.9
# 3  Robert Downey Jr.  Avengers: Endgame   Action   8.4

# %%
movieData.at[0, "Actor"]
# Out:
# 'Leonardo DiCaprio'

# %%
movieData[movieData['IMDB']>8][['Actor', 'Film', 'Genre', 'IMDB']]
# Out:
#                 Actor                      Film      Genre  IMDB
# 0   Leonardo DiCaprio                 Inception     Sci-Fi   8.8
# 3   Robert Downey Jr.         Avengers: Endgame     Action   8.4
# 4      Christian Bale           The Dark Knight     Action   9.0
# 5      Christian Bale             Batman Begins     Action   8.2
# 6           Tom Hanks              Forrest Gump      Drama   8.8
# 8        Keanu Reeves                The Matrix     Sci-Fi   8.7
# 10          Brad Pitt                Fight Club      Drama   8.8
# 12        Johnny Depp  Pirates of the Caribbean  Adventure   8.1
# 19        Chris Evans    Avengers: Infinity War     Action   8.4
# 24     Morgan Freeman      Shawshank Redemption      Drama   9.3
# 25     Morgan Freeman                     Se7en      Crime   8.6
# 28       Hugh Jackman                     Logan     Action   8.1
# 29       Hugh Jackman              The Prestige      Drama   8.5
# ...

# %%
movieData[(movieData['IMDB']>8) & (movieData['Year']>1990)][['Actor', 'Film', 'Genre', 'Year', 'IMDB']]
# Out:
#                 Actor                      Film      Genre  Year  IMDB
# 0   Leonardo DiCaprio                 Inception     Sci-Fi  2010   8.8
# 3   Robert Downey Jr.         Avengers: Endgame     Action  2019   8.4
# 4      Christian Bale           The Dark Knight     Action  2008   9.0
# 5      Christian Bale             Batman Begins     Action  2005   8.2
# 6           Tom Hanks              Forrest Gump      Drama  1994   8.8
# 8        Keanu Reeves                The Matrix     Sci-Fi  1999   8.7
# 10          Brad Pitt                Fight Club      Drama  1999   8.8
# 12        Johnny Depp  Pirates of the Caribbean  Adventure  2003   8.1
# 19        Chris Evans    Avengers: Infinity War     Action  2018   8.4
# 24     Morgan Freeman      Shawshank Redemption      Drama  1994   9.3
# 25     Morgan Freeman                     Se7en      Crime  1995   8.6
# 28       Hugh Jackman                     Logan     Action  2017   8.1
# ...

# %%
movieData.query("Year > 2000 and IMDB > 8")
# Out:
#                 Actor                      Film  Year      Genre  BoxOffice  \
# 0   Leonardo DiCaprio                 Inception  2010     Sci-Fi        836
# 3   Robert Downey Jr.         Avengers: Endgame  2019     Action       2797
# 4      Christian Bale           The Dark Knight  2008     Action       1005
# 5      Christian Bale             Batman Begins  2005     Action        373
# 12        Johnny Depp  Pirates of the Caribbean  2003  Adventure        654
# 19        Chris Evans    Avengers: Infinity War  2018     Action       2048
# 28       Hugh Jackman                     Logan  2017     Action        619
# 29       Hugh Jackman              The Prestige  2006      Drama        109
# 32      Mark Wahlberg              The Departed  2006      Crime        291
# 38    Joaquin Phoenix                     Joker  2019      Drama       1074
# 43       Henry Cavill               The Witcher  2019    Fantasy         90
#
#     IMDB
# 0    8.8
# 3    8.4
# 4    9.0
# 5    8.2
# ...

# %%
movieData.query("Actor == 'Leonardo DiCaprio' and IMDB > 8")[["Actor", "Film"]]
# Out:
#                Actor       Film
# 0  Leonardo DiCaprio  Inception

# %%
movieData.query("Actor == 'Leonardo DiCaprio' and IMDB > 8")[["Actor", "Film"]]
# Out:
# Empty DataFrame
# Columns: [Actor, Film]
# Index: []

# %%
movieData
# Out:
#                    Actor                      Film  Year      Genre  \
# 0                 Aditya                 Inception  2010     Sci-Fi
# 1      Leonardo DiCaprio                   Titanic  1997    Romance
# 2      Robert Downey Jr.                  Iron Man  2008     Action
# 3      Robert Downey Jr.         Avengers: Endgame  2019     Action
# 4         Christian Bale           The Dark Knight  2008     Action
# 5         Christian Bale             Batman Begins  2005     Action
# 6              Tom Hanks              Forrest Gump  1994      Drama
# 7              Tom Hanks                 Cast Away  2000      Drama
# 8           Keanu Reeves                The Matrix  1999     Sci-Fi
# 9           Keanu Reeves                 John Wick  2014     Action
# 10             Brad Pitt                Fight Club  1999      Drama
# 11             Brad Pitt               World War Z  2013     Action
# 12           Johnny Depp  Pirates of the Caribbean  2003  Adventure
# ...

# %%
movieData
# Out:
#                    Actor                      Film  Year      Genre  \
# 0                 Aditya                 Inception  2010     Sci-Fi
# 1      Leonardo DiCaprio                   Titanic  1997    Romance
# 2      Robert Downey Jr.                  Iron Man  2008     Action
# 3      Robert Downey Jr.         Avengers: Endgame  2019     Action
# 4         Christian Bale           The Dark Knight  2008     Action
# 5         Christian Bale             Batman Begins  2005     Action
# 6              Tom Hanks              Forrest Gump  1994      Drama
# 7              Tom Hanks                 Cast Away  2000      Drama
# 8           Keanu Reeves                The Matrix  1999     Sci-Fi
# 9           Keanu Reeves                 John Wick  2014     Action
# 10             Brad Pitt                Fight Club  1999      Drama
# 11             Brad Pitt               World War Z  2013     Action
# 12           Johnny Depp  Pirates of the Caribbean  2003  Adventure
# ...
